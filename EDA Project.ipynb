# %% [markdown]
# #Importing required libraries

# %%
import pandas as pd

# %% [markdown]
# #Loading a File

# %%
df=pd.read_csv("data.csv",encoding="ISO-8859-1")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #Number of rows and columns

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# #Access First Five Rows

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #Access Last Five Rows

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# #Displaying Total Columns

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %% [markdown]
# #Getting All Columns one by one

# %%
for col in df.columns:
    print(col)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %% [markdown]
# #Renaming Columns Name

# %%
d = {
        'InvoiceNo': 'invoice_num',
        'StockCode' : 'stock_code',
        'Description' : 'description',
        'Quantity' : 'quantity',
        'InvoiceDate' : 'invoice_date',
        'UnitPrice' : 'unit_price',
        'CustomerID' : 'cust_id',
        'Country' : 'country'
}

# %%
d
# Out:
# {'InvoiceNo': 'invoice_num',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'cust_id',
#  'Country': 'country'}

# %%
df.rename(columns=d,inplace=True)

# %% [markdown]
# #After changing column names Checking new column names

# %%
df.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country'],
#       dtype='str')

# %%
for col in df.columns:
    print(col)
# Out:
# invoice_num
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country

# %% [markdown]
# #Lets check initial data

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %%
df.tail()
# Out:
#        invoice_num stock_code                      description  quantity  \
# 541904      581587      22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905      581587      22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906      581587      23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      581587      23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908      581587      22138    BAKING SET 9 PIECE RETROSPOT          3
#
#            invoice_date  unit_price  cust_id country
# 541904  12/9/2011 12:50        0.85  12680.0  France
# 541905  12/9/2011 12:50        2.10  12680.0  France
# 541906  12/9/2011 12:50        4.15  12680.0  France
# 541907  12/9/2011 12:50        4.15  12680.0  France
# 541908  12/9/2011 12:50        4.95  12680.0  France

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# #Checking column types

# %%
df.dtypes
# Out:
# invoice_num         str
# stock_code          str
# description         str
# quantity          int64
# invoice_date        str
# unit_price      float64
# cust_id         float64
# country             str
# dtype: object

# %% [markdown]
# #DataFrame information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  str
#  1   stock_code    541909 non-null  str
#  2   description   540455 non-null  str
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  str
#  5   unit_price    541909 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %% [markdown]
# Checking missing values for each column

# %%
df.isna()
# Out:
#         invoice_num  stock_code  description  quantity  invoice_date  \
# 0             False       False        False     False         False
# 1             False       False        False     False         False
# 2             False       False        False     False         False
# 3             False       False        False     False         False
# 4             False       False        False     False         False
# ...             ...         ...          ...       ...           ...
# 541904        False       False        False     False         False
# 541905        False       False        False     False         False
# 541906        False       False        False     False         False
# 541907        False       False        False     False         False
# 541908        False       False        False     False         False
#
#         unit_price  cust_id  country
# 0            False    False    False
# 1            False    False    False
# ...

# %%
df.isna().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# cust_id         135080
# country              0
# dtype: int64

# %% [markdown]
# #sorting the missing values in descending order

# %%
s=df.isna().sum().sort_values(ascending=False)
print(s)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# #To Print the columns name with the missing values

# %%
con=s.values>0
print(s[con])
# Out:
# cust_id        135080
# description      1454
# dtype: int64

# %% [markdown]
# Checkcing number of columns

# %%
len(df)
# Out:
# 541909

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# #Checking type of invoice_date column

# %%
df.dtypes
# Out:
# invoice_num         str
# stock_code          str
# description         str
# quantity          int64
# invoice_date        str
# unit_price      float64
# cust_id         float64
# country             str
# dtype: object

# %% [markdown]
# #Converting invoice_date data type into datatime data type

# %%
df["invoice_date"]=pd.to_datetime(df["invoice_date"])

# %% [markdown]
# #Checking invoice date after chnging the data type

# %%
df.dtypes
# Out:
# invoice_num                str
# stock_code                 str
# description                str
# quantity                 int64
# invoice_date    datetime64[us]
# unit_price             float64
# cust_id                float64
# country                    str
# dtype: object

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# Checking Description Column

# %%
df["description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: str

# %% [markdown]
# #to covert the description to lower case

# %%
df.description.str.lower()
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 541909, dtype: str

# %%
df.head(3)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
# 2      536365     84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom

# %%
df["description"]=df["description"].str.lower()

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# #Missing Values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# #Droping Missing Values

# %% [markdown]
# #Dropping Missing values

# %%
new_df=df.dropna()

# %%
new_df
# Out:
#        invoice_num stock_code                          description  quantity  \
# 0           536365     85123A   white hanging heart t-light holder         6
# 1           536365      71053                  white metal lantern         6
# 2           536365     84406B       cream cupid hearts coat hanger         8
# 3           536365     84029G  knitted union flag hot water bottle         6
# 4           536365     84029E       red woolly hottie white heart.         6
# ...            ...        ...                                  ...       ...
# 541904      581587      22613          pack of 20 spaceboy napkins        12
# 541905      581587      22899         children's apron dolly girl          6
# 541906      581587      23254        childrens cutlery dolly girl          4
# 541907      581587      23255      childrens cutlery circus parade         4
# 541908      581587      22138        baking set 9 piece retrospot          3
#
# ...

# %% [markdown]
# #After dropping missing values we are checking Whether the missing values are present are not

# %%
new_df.isna().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %% [markdown]
# DataFrame Information

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  str
#  1   stock_code    406829 non-null  str
#  2   description   406829 non-null  str
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[us]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), str(4)
# memory usage: 27.9 MB

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# Check datatype of the cust_id

# %%
new_df.dtypes
# Out:
# invoice_num                str
# stock_code                 str
# description                str
# quantity                 int64
# invoice_date    datetime64[us]
# unit_price             float64
# cust_id                float64
# country                    str
# dtype: object

# %%
new_df["cust_id"]=new_df["cust_id"].astype("int64")

# %%
new_df.dtypes
# Out:
# invoice_num                str
# stock_code                 str
# description                str
# quantity                 int64
# invoice_date    datetime64[us]
# unit_price             float64
# cust_id                  int64
# country                    str
# dtype: object

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# DataFrame Description

# %%
new_df.describe()
# Out:
#             quantity                invoice_date     unit_price        cust_id
# count  406829.000000                      406829  406829.000000  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207       3.460471   15287.690570
# min    -80995.000000         2010-12-01 08:26:00       0.000000   12346.000000
# 25%         2.000000         2011-04-06 15:02:00       1.250000   13953.000000
# 50%         5.000000         2011-07-31 11:48:00       1.950000   15152.000000
# 75%        12.000000         2011-10-20 13:06:00       3.750000   16791.000000
# max     80995.000000         2011-12-09 12:50:00   38970.000000   18287.000000
# std       248.693370                         NaN      69.315162    1713.600303

# %%
new_df.describe().round(2)
# Out:
#         quantity                invoice_date  unit_price    cust_id
# count  406829.00                      406829   406829.00  406829.00
# mean       12.06  2011-07-10 16:30:57.879207        3.46   15287.69
# min    -80995.00         2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00         2011-04-06 15:02:00        1.25   13953.00
# 50%         5.00         2011-07-31 11:48:00        1.95   15152.00
# 75%        12.00         2011-10-20 13:06:00        3.75   16791.00
# max     80995.00         2011-12-09 12:50:00    38970.00   18287.00
# std       248.69                         NaN       69.32    1713.60

# %% [markdown]
# Let us do some analysis

# %% [markdown]
# Conclusion is: quantity column having negative values

# %% [markdown]
# So, we need to remove/delete negative values

# %% [markdown]
# Example to delete negative values from list object

# %%
l=[10,20,-1,0,-2]

# %%
for val in l:
    if val>=0:
        print(val)
# Out:
# 10
# 20
# 0

# %% [markdown]
# Remove negative values from quantity column

# %%
new_df["quantity"]>0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: quantity, Length: 406829, dtype: bool

# %%
con=new_df["quantity"]>0

# %%
new_df=new_df[con]

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   397924 non-null  str
#  1   stock_code    397924 non-null  str
#  2   description   397924 non-null  str
#  3   quantity      397924 non-null  int64
#  4   invoice_date  397924 non-null  datetime64[us]
#  5   unit_price    397924 non-null  float64
#  6   cust_id       397924 non-null  int64
#  7   country       397924 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(2), str(4)
# memory usage: 27.3 MB

# %%
new_df.describe().round(2)
# Out:
#         quantity                invoice_date  unit_price    cust_id
# count  397924.00                      397924   397924.00  397924.00
# mean       13.02  2011-07-10 23:43:36.912476        3.12   15294.32
# min         1.00         2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00         2011-04-07 11:12:00        1.25   13969.00
# 50%         6.00         2011-07-31 14:39:00        1.95   15159.00
# 75%        12.00         2011-10-20 14:33:00        3.75   16795.00
# max     80995.00         2011-12-09 12:50:00     8142.75   18287.00
# std       180.42                         NaN       22.10    1713.17

# %% [markdown]
# Accessing Initial Data

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# Checking total number of rows and columns

# %%
new_df.shape
# Out:
# (397924, 8)

# %% [markdown]
# Adding the column Amount spent

# %%
new_df["amount_spent"]=new_df["unit_price"]*new_df["quantity"]

# %%
new_df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %% [markdown]
# Reading the one by one columns name from data frame

# %%
for col in new_df.columns:
    print(col)
# Out:
# invoice_num
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country
# amount_spent

# %% [markdown]
# Rearranging the columns name

# %%
col_order=['invoice_num','invoice_date','stock_code','description','quantity','unit_price','amount_spent','cust_id','country']

# %%
new_df=new_df[col_order]

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# let us do analysis on invoice date column

# %% [markdown]
# Number of columns in the dataset

# %%
len(new_df.columns)
# Out:
# 9

# %% [markdown]
# Accessing invoice_date column

# %%
#method 1
new_df["invoice_date"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[us]

# %%
#method 2
new_df.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[us]

# %% [markdown]
# Accessing year value from invoice_date

# %%
new_df["invoice_date"].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# Accessing month value from invoice_date

# %%
new_df["invoice_date"].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32

# %% [markdown]
# Accessing date value from invoice_date

# %%
new_df["invoice_date"].dt.date
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: invoice_date, Length: 397924, dtype: object

# %% [markdown]
# Access initial data frame

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# Lets insert year_month colum in 2nd position

# %% [markdown]
# small calculation

# %%
y=2010
m=12

# %%
y_m=y*100+m

# %%
y_m
# Out:
# 201012

# %% [markdown]
# Beginer level

# %%
v1=new_df["invoice_date"].map(lambda col:100*(col.year)+col.month)

# %%
new_df.insert(2,"year_month",v1)

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     85123A
# 1      536365 2010-12-01 08:26:00      201012      71053
# 2      536365 2010-12-01 08:26:00      201012     84406B
# 3      536365 2010-12-01 08:26:00      201012     84029G
# 4      536365 2010-12-01 08:26:00      201012     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# Adding month column to the exisint DataFrame

# %%
new_df.insert(3,"month",df["invoice_date"].dt.month)

# %%
new_df.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12     85123A
# 1      536365 2010-12-01 08:26:00      201012     12      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %%
df["invoice_date"].dt.dayofweek
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 541904    4
# 541905    4
# 541906    4
# 541907    4
# 541908    4
# Name: invoice_date, Length: 541909, dtype: int32

# %% [markdown]
# Adding month column to the exisint DataFrame

# %%
new_df.insert(4,"day",(df["invoice_date"].dt.dayofweek)+1)

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# ...

# %% [markdown]
# Adding hour column to the existing dataframe

# %%
new_df.insert(5,"hour",new_df["invoice_date"].dt.hour)

# %%
new_df.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %% [markdown]
# Displaying all columns name

# %%
new_df.columns
# Out:
# Index(['invoice_num', 'invoice_date', 'year_month', 'month', 'day', 'hour',
#        'stock_code', 'description', 'quantity', 'unit_price', 'amount_spent',
#        'cust_id', 'country'],
#       dtype='str')

# %%
for col in new_df.columns:
    print(col)
# Out:
# invoice_num
# invoice_date
# year_month
# month
# day
# hour
# stock_code
# description
# quantity
# unit_price
# amount_spent
# cust_id
# country

# %% [markdown]
# Explotory Data Analysis

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
len(new_df["cust_id"].unique())
# Out:
# 4339

# %%
new_df.groupby(by=["cust_id","country"])["invoice_num"].count()
# Out:
# cust_id  country
# 12346    United Kingdom      1
# 12347    Iceland           182
# 12348    Finland            31
# 12349    Italy              73
# 12350    Norway             17
#                           ...
# 18280    United Kingdom     10
# 18281    United Kingdom      7
# 18282    United Kingdom     12
# 18283    United Kingdom    756
# 18287    United Kingdom     70
# Name: invoice_num, Length: 4347, dtype: int64

# %%
con=df["cust_id"]==12347

# %%
len(new_df[con])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1516\3306345023.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(new_df[con])
# 182

# %%
new_df.groupby(by=["invoice_num"],as_index=False)["amount_spent"].sum()
# Out:
#       invoice_num  amount_spent
# 0          536365        139.12
# 1          536366         22.20
# 2          536367        278.73
# 3          536368         70.05
# 4          536369         17.85
# ...           ...           ...
# 18531      581583        124.60
# 18532      581584        140.64
# 18533      581585        329.05
# 18534      581586        339.20
# 18535      581587        249.45
#
# [18536 rows x 2 columns]

# %%
new_df.groupby(by=["cust_id"],as_index=False)["amount_spent"].sum()
# Out:
#       cust_id  amount_spent
# 0       12346      77183.60
# 1       12347       4310.00
# 2       12348       1797.24
# 3       12349       1757.55
# 4       12350        334.40
# ...       ...           ...
# 4334    18280        180.60
# 4335    18281         80.82
# 4336    18282        178.05
# 4337    18283       2094.88
# 4338    18287       1837.28
#
# [4339 rows x 2 columns]

# %%
new_df.groupby(by=["country"])["amount_spent"].sum().sort_values(ascending=False)
# Out:
# country
# United Kingdom          7308391.554
# Netherlands              285446.340
# EIRE                     265545.900
# Germany                  228867.140
# France                   209024.050
# Australia                138521.310
# Spain                     61577.110
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38378.330
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33439.890
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20450.440
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13590.380
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7221.690
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# USA                        3580.390
# ...

# %% [markdown]
# Data Visualization Libraries

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
orders=df.groupby(by=["cust_id","country"],as_index=False)["invoice_num"].count()

# %%
orders
# Out:
#       cust_id         country  invoice_num
# 0     12346.0  United Kingdom            2
# 1     12347.0         Iceland          182
# 2     12348.0         Finland           31
# 3     12349.0           Italy           73
# 4     12350.0          Norway           17
# ...       ...             ...          ...
# 4375  18280.0  United Kingdom           10
# 4376  18281.0  United Kingdom            7
# 4377  18282.0  United Kingdom           13
# 4378  18283.0  United Kingdom          756
# 4379  18287.0  United Kingdom           70
#
# [4380 rows x 3 columns]

# %% [markdown]
# checking top 5 number of orders

# %%
orders.sort_values(by='invoice_num',ascending=False).head()
# Out:
#       cust_id         country  invoice_num
# 4050  17841.0  United Kingdom         7983
# 1903  14911.0            EIRE         5903
# 1308  14096.0  United Kingdom         5128
# 338   12748.0  United Kingdom         4642
# 1682  14606.0  United Kingdom         2782

# %% [markdown]
# Visualizing - Number of Orders for different Customers

# %%
plt.subplots(figsize=(15,6))

plt.plot(orders.cust_id, orders.invoice_num)

plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')

plt.show()

# %% [markdown]
# How much money spent by each customers

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
new_df.groupby(by=["cust_id"],as_index=False)["amount_spent"].sum()
# Out:
#       cust_id  amount_spent
# 0       12346      77183.60
# 1       12347       4310.00
# 2       12348       1797.24
# 3       12349       1757.55
# 4       12350        334.40
# ...       ...           ...
# 4334    18280        180.60
# 4335    18281         80.82
# 4336    18282        178.05
# 4337    18283       2094.88
# 4338    18287       1837.28
#
# [4339 rows x 2 columns]

# %%
new_df.groupby(by=["cust_id"])["amount_spent"].sum()
# Out:
# cust_id
# 12346    77183.60
# 12347     4310.00
# 12348     1797.24
# 12349     1757.55
# 12350      334.40
#            ...
# 18280      180.60
# 18281       80.82
# 18282      178.05
# 18283     2094.88
# 18287     1837.28
# Name: amount_spent, Length: 4339, dtype: float64

# %%
money_spent=new_df.groupby(by=["cust_id"],as_index=False)["amount_spent"].sum()

# %%
money_spent
# Out:
#       cust_id  amount_spent
# 0       12346      77183.60
# 1       12347       4310.00
# 2       12348       1797.24
# 3       12349       1757.55
# 4       12350        334.40
# ...       ...           ...
# 4334    18280        180.60
# 4335    18281         80.82
# 4336    18282        178.05
# 4337    18283       2094.88
# 4338    18287       1837.28
#
# [4339 rows x 2 columns]

# %% [markdown]
# Top FIVE customers who spend highest money

# %%
money_spent.sort_values(by="amount_spent",ascending=False).head()
# Out:
#       cust_id  amount_spent
# 1690    14646     280206.02
# 4202    18102     259657.30
# 3729    17450     194550.79
# 3009    16446     168472.50
# 1880    14911     143825.06

# %% [markdown]
# Top TEN customers who spend highest money

# %%
money_spent.sort_values(by="amount_spent",ascending=False).head(10)
# Out:
#       cust_id  amount_spent
# 1690    14646     280206.02
# 4202    18102     259657.30
# 3729    17450     194550.79
# 3009    16446     168472.50
# 1880    14911     143825.06
# 55      12415     124914.53
# 1334    14156     117379.63
# 3772    17511      91062.38
# 2703    16029      81024.84
# 0       12346      77183.60

# %% [markdown]
# Visualizing - Money spent for different customers

# %%
plt.subplots(figsize=(15,6))

plt.plot(money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')

plt.show()

# %%
new_df["description"].unique()
# Out:
# <StringArray>
# [ 'white hanging heart t-light holder',                 'white metal lantern',
#       'cream cupid hearts coat hanger', 'knitted union flag hot water bottle',
#       'red woolly hottie white heart.',        'set 7 babushka nesting boxes',
#    'glass star frosted t-light holder',              'hand warmer union jack',
#            'hand warmer red polka dot',       'assorted colour bird ornament',
#  ...
#      'silver and black orbit necklace',           'letter "f" bling key ring',
#            'letter "o" bling key ring',           'letter "t" bling key ring',
#            'letter "u" bling key ring',           'letter "w" bling key ring',
#            'letter "z" bling key ring',      'pink crystal skull phone charm',
#   'cream hanging heart t-light holder',         'paper craft , little birdie']
# Length: 3877, dtype: str

# %%
new_df["year_month"].unique()
# Out:
# array([201012, 201101, 201102, 201103, 201104, 201105, 201106, 201107,
#        201108, 201109, 201110, 201111, 201112])

# %%
new_df.groupby('year_month')['invoice_num'].unique()
# Out:
# year_month
# 201012    [536365, 536366, 536367, 536368, 536369, 53637...
# 201101    [539993, 540001, 540002, 540003, 540004, 54000...
# 201102    [542776, 542777, 542778, 542779, 542780, 54278...
# 201103    [545220, 545221, 545222, 545223, 545224, 54522...
# 201104    [548550, 548551, 548552, 548553, 548554, 54855...
# 201105    [551515, 551516, 551517, 551518, 551519, 55152...
# 201106    [555156, 555157, 555158, 555159, 555160, 55516...
# 201107    [558638, 558639, 558640, 558641, 558642, 55864...
# 201108    [561904, 561905, 561906, 561907, 561908, 56190...
# 201109    [565080, 565082, 565083, 565084, 565086, 56508...
# 201110    [569203, 569204, 569205, 569206, 569207, 56920...
# 201111    [573744, 573745, 573746, 573747, 573748, 57374...
# 201112    [579899, 579900, 579901, 579910, 579916, 57991...
# Name: invoice_num, dtype: object

# %%
new_df.groupby(by=["invoice_num"])["year_month"].unique()
# Out:
# invoice_num
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 581583    [201112]
# 581584    [201112]
# 581585    [201112]
# 581586    [201112]
# 581587    [201112]
# Name: year_month, Length: 18536, dtype: object

# %%
new_df.groupby(by=["invoice_num"])["year_month"].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
new_df.groupby(by=["invoice_num"])["year_month"].unique().value_counts().sort_index()
# Out:
# year_month
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: count, dtype: int64

# %%
ax = new_df.groupby('invoice_num')['year_month'].unique().value_counts().sort_index().plot(kind = 'bar',figsize = (15,6))

ax.set_xlabel('Month and Year',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)', fontsize = 15)

t = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11')

ax.set_xticklabels(t, rotation='horizontal', fontsize=13)

plt.show()

# %% [markdown]
# How many orders (per day)

# %%
new_df.groupby('day')['invoice_num'].unique()
# Out:
# day
# 1    [537226, 537227, 537228, 537229, 537231, 53723...
# 2    [537446, 537447, 537448, 537456, 537457, 53745...
# 3    [536365, 536366, 536367, 536368, 536369, 53637...
# 4    [536598, 536599, 536600, 536601, 536602, 53660...
# 5    [536847, 536848, 536849, 536851, 536852, 53685...
# 7    [537037, 537038, 537040, 537041, 537042, 53704...
# Name: invoice_num, dtype: object

# %%
new_df.groupby('invoice_num')['day'].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
new_df.groupby('invoice_num')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
new_df.groupby('invoice_num')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
ax = new_df.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(kind = 'bar',figsize=(15,6))

ax.set_xlabel('Day',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Days',fontsize=15)
d = ('Mon','Tue','Wed','Thur','Fri','Sun')
ax.set_xticklabels(d, rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# Discover patterns for Unit Price

# %%
new_df["unit_price"].describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %% [markdown]
# Min value for product is zero, so there are some free products

# %%
# check the distribution of unit price
plt.subplots(figsize = (12,6))

sns.boxplot(new_df.unit_price)
plt.show()

# %% [markdown]
# Filter only free products(cost = 0)

# %%
df_free = new_df[new_df.unit_price == 0]

# %%
len(df_free)
# Out:
# 40

# %%
df_free["year_month"]
# Out:
# 9302      201012
# 33576     201012
# 40089     201012
# 47068     201101
# 47070     201101
# 56674     201101
# 86789     201102
# 130188    201103
# 139453    201103
# 145208    201104
# 157042    201104
# 187613    201105
# 198383    201105
# 279324    201107
# 282912    201107
# 285657    201108
# 298054    201108
# 314745    201108
# 314746    201108
# 314747    201108
# 314748    201108
# 358655    201109
# 361825    201109
# 379913    201110
# 395529    201110
# 420404    201110
# 436428    201111
# 436597    201111
# 436961    201111
# 439361    201111
# 446125    201111
# 446793    201111
# 446794    201111
# 454463    201111
# 454464    201111
# 479079    201111
# 479546    201111
# 480649    201111
# 485985    201111
# 502122    201111
# Name: year_month, dtype: int64

# %%
df_free["year_month"].value_counts()
# Out:
# year_month
# 201111    14
# 201108     6
# 201012     3
# 201101     3
# 201110     3
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free["year_month"].value_counts().sort_index()
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
ax = df_free.year_month.value_counts().sort_index().plot(kind = 'bar',figsize=(12,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)

m = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11')

ax.set_xticklabels(m, rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# How many orders for each country

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
new_df.groupby(by='country')["invoice_num"].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
new_df.groupby(by='country')["invoice_num"].count().sort_values()
# Out:
# country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# ...

# %% [markdown]
# How many orders for each country

# %%
group_country_orders = new_df.groupby('country')['invoice_num'].count().sort_values()
# del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)

plt.subplots(figsize=(15,8))

group_country_orders.plot(kind='barh', fontsize=12)

plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = new_df.groupby('country')['invoice_num'].count().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)

plt.subplots(figsize=(15,8))

group_country_orders.plot(kind='barh', fontsize=12)

plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# How much money spent by each country

# %%
new_df
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# ...

# %%
new_df.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     548.400
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     265545.900
# European Community         1300.250
# Finland                   22546.080
# France                   209024.050
# Germany                  228867.140
# Greece                     4760.520
# Iceland                    4310.000
# Israel                     7221.690
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# ...

# %%
new_df.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# ...

# %%
new_df.groupby('country')['amount_spent'].sum().sort_values(ascending=False)
# Out:
# country
# United Kingdom          7308391.554
# Netherlands              285446.340
# EIRE                     265545.900
# Germany                  228867.140
# France                   209024.050
# Australia                138521.310
# Spain                     61577.110
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38378.330
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33439.890
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20450.440
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13590.380
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7221.690
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# USA                        3580.390
# ...

# %%
group_country_orders = new_df.groupby('country')['amount_spent'].sum().sort_values()
# del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)

plt.subplots(figsize=(15,8))

group_country_orders.plot(kind='barh', fontsize=12)

plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = new_df.groupby('country')['amount_spent'].sum().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)

plt.subplots(figsize=(15,8))

group_country_orders.plot(kind='barh', fontsize=12)

plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()
